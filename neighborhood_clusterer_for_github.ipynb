# %% [markdown]
# # clusterer

# %% [markdown]
# Foursquare API keys and version

# %%
CLIENT_ID = 'redacted for github'
CLIENT_SECRET = 'redacted for github'
VERSION = '20180605'

# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import requests
import folium
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# set wiki page URL

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# read webpage and store as 'tables'

# %%
tables = pd.read_html(url, header=0)

# %% [markdown]
# since there are multiple tables, set a list of the headings of the table we're interested in

# %%
headings = ['Postcode', 'Borough', 'Neighbourhood']

# %% [markdown]
# loop over the tables in the webpage, and if the current table in the loop's headings match the headings we're interested in, we've found the table; thus exit the loop

# %%
for table in tables:
    current_headings = table.columns.values[:4]
    if all(current_headings == headings):
        break

# %% [markdown]
# filter out postcodes without boroughs

# %%
codes = table[table.Borough != 'Not assigned']

# %% [markdown]
# create a new dataframe grouping by postcode+borough combinations and aggregating neighborhoods into a comma-separated list

# %%
agg = codes.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).to_frame()

# %% [markdown]
# reset the index of the aggregated dataframe and save it to a new dataframe

# %%
agg2 = agg.reset_index()

# %% [markdown]
# ##### note
# I abaonded geocoder because Anaconda couldn't install it correctly

# %% [markdown]
# set URL of lat/lon data

# %%
backup_url = 'http://cocl.us/Geospatial_data'

# %% [markdown]
# read file and store lat/lon data as 'geo_data'

# %%
geo_data = pd.read_csv(backup_url)

# %% [markdown]
# add the latitude and longitude columns to the aggregated and indexed dataframe

# %%
agg2['Latitude'] = geo_data['Latitude']
agg2['Longitude'] = geo_data['Longitude']

# %% [markdown]
# set search radius (in meters) and response limit for the Foursquare API call
#
# note that the radius was increased from 500 to 1000 because the example neighborhood I tried exploring didn't return any venues with a 500 meter radius

# %%
radius = 1000
limit = 100

# %% [markdown]
# define a function to make the Foursquare API calls for each postcode in the dataframe

# %%
def getVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat,
            lng,
            radius,
            limit)
        
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [
            'Neighborhood',
            'Neighborhood latitude',
            'Neighborhood longitude',
            'Venue',
            'Venue latitude',
            'Venue longitude',
            'Venue category']
        
    return(nearby_venues)

# %% [markdown]
# invoke the Foursquare API call function for each row in agg2, the dataframe of postcode+borough combinations

# %%
toronto_venues = getVenues(names=agg2['Neighbourhood'],
                          latitudes=agg2['Latitude'],
                          longitudes=agg2['Longitude'])
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest

# %% [markdown]
# display the resultant dataframe

# %%
toronto_venues
# Out:
#                                            Neighborhood  \
# 0                                        Rouge, Malvern
# 1                                        Rouge, Malvern
# 2                                        Rouge, Malvern
# 3                                        Rouge, Malvern
# 4                                        Rouge, Malvern
# ...                                                 ...
# 4908  Albion Gardens, Beaumond Heights, Humbergate, ...
# 4909  Albion Gardens, Beaumond Heights, Humbergate, ...
# 4910  Albion Gardens, Beaumond Heights, Humbergate, ...
# 4911                                          Northwest
# 4912                                          Northwest
#
#       Neighborhood latitude  Neighborhood longitude                 Venue  \
# 0                 43.806686              -79.194353               Wendy's
# 1                 43.806686              -79.194353               Wendy's
# 2                 43.806686              -79.194353              Harvey's
# 3                 43.806686              -79.194353        Caribbean Wave
# 4                 43.806686              -79.194353   Staples Morningside
# ...                     ...                     ...                   ...
# 4908              43.739416              -79.588437      Caribbean Heat 2
# 4909              43.739416              -79.588437  46 Martingrove North
# 4910              43.739416              -79.588437         Panorama Park
# 4911              43.706748              -79.594054           Tim Hortons
# 4912              43.706748              -79.594054         Saand Rexdale
#
#       Venue latitude  Venue longitude                 Venue category
# 0          43.802008       -79.198080           Fast Food Restaurant
# 1          43.807448       -79.199056           Fast Food Restaurant
# 2          43.800020       -79.198307                     Restaurant
# 3          43.798558       -79.195777           Caribbean Restaurant
# 4          43.800285       -79.196607  Paper / Office Supplies Store
# ...              ...              ...                            ...
# 4908       43.743186       -79.582367           Caribbean Restaurant
# 4909       43.732211       -79.589618                       Bus Line
# 4910       43.747021       -79.583497                           Park
# 4911       43.714657       -79.593716                    Coffee Shop
# 4912       43.705072       -79.598725                      Drugstore
#
# [4913 rows x 7 columns]

# %% [markdown]
# one-hot encode the venue values

# %%
onehot = pd.get_dummies(toronto_venues[['Venue category']], prefix='', prefix_sep='')
onehot['Neighborhood'] = toronto_venues['Neighborhood']
fixed_columns = [onehot.columns[-1]] + list(onehot.columns[:-1])
onehot = onehot[fixed_columns]

# %% [markdown]
# group the results by neighborhood and take the mean of component one-hot encoded venue categories to measure how frequently each venue type appears in each neighborhood

# %%
grouped = onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# write out the top five venue categories for each neighborhood

# %%
top_what = 5

for hood in grouped['Neighborhood']:
    print('----'+hood+'----')
    temp = grouped[grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue', 'freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(top_what))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#          venue  freq
# 0         Café  0.06
# 1  Coffee Shop  0.06
# 2        Hotel  0.05
# 3      Theater  0.04
# 4   Restaurant  0.04
#
#
# ----Agincourt----
#                   venue  freq
# 0    Chinese Restaurant  0.13
# 1         Shopping Mall  0.04
# 2            Restaurant  0.04
# 3                Bakery  0.04
# 4  Caribbean Restaurant  0.04
#
#
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
#                 venue  freq
# 0  Chinese Restaurant  0.14
# 1                Park  0.07
# 2        Noodle House  0.07
# 3         Pizza Place  0.07
# 4              Bakery  0.07
#
#
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
#                   venue  freq
# 0           Pizza Place  0.20
# 1         Grocery Store  0.15
# 2  Fast Food Restaurant  0.05
# 3        Discount Store  0.05
# 4                  Park  0.05
#
#
# ----Alderwood, Long Branch----
#             venue  freq
# 0        Pharmacy  0.12
# 1  Discount Store  0.12
# 2     Pizza Place  0.08
# 3             Gym  0.04
# 4     Coffee Shop  0.04
#
#
# ----Bathurst Manor, Downsview North, Wilson Heights----
#               venue  freq
# 0       Coffee Shop  0.07
# 1    Ice Cream Shop  0.03
# 2          Ski Area  0.03
# 3  Sushi Restaurant  0.03
# 4       Men's Store  0.03
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Bank  0.14
# 1          Gas Station  0.14
# 2  Japanese Restaurant  0.14
# 3                 Park  0.07
# 4   Chinese Restaurant  0.07
#
#
# ----Bedford Park, Lawrence Manor East----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1           Coffee Shop  0.08
# 2            Restaurant  0.05
# 3  Fast Food Restaurant  0.05
# 4        Sandwich Place  0.05
#
#
# ----Berczy Park----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.06
# 2           Restaurant  0.06
# 3  Japanese Restaurant  0.05
# 4                Hotel  0.05
#
#
# ----Birch Cliff, Cliffside West----
#                venue  freq
# 0  Convenience Store  0.08
# 1           Gym Pool  0.08
# 2     Ice Cream Shop  0.08
# 3    Thai Restaurant  0.08
# 4               Park  0.08
#
#
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
#                     venue  freq
# 0                    Park  0.10
# 1             Coffee Shop  0.10
# 2  Transportation Service  0.05
# 3       Fish & Chips Shop  0.05
# 4                    Café  0.05
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#          venue  freq
# 0         Café  0.09
# 1  Coffee Shop  0.06
# 2          Bar  0.05
# 3   Restaurant  0.04
# 4       Bakery  0.04
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                 venue  freq
# 0                Park  0.10
# 1             Brewery  0.06
# 2         Coffee Shop  0.06
# 3         Pizza Place  0.06
# 4  Italian Restaurant  0.04
#
#
# ----CFB Toronto, Downsview East----
#                 venue  freq
# 0         Coffee Shop  0.13
# 1  Turkish Restaurant  0.09
# 2      Sandwich Place  0.04
# 3        Soccer Field  0.04
# 4                Café  0.04
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#              venue  freq
# 0      Coffee Shop  0.20
# 1  Harbor / Marina  0.13
# 2   Scenic Lookout  0.07
# 3             Park  0.07
# 4           Garden  0.07
#
#
# ----Cabbagetown, St. James Town----
#         venue  freq
# 0       Diner  0.05
# 1        Park  0.05
# 2        Café  0.05
# 3  Restaurant  0.05
# 4   Gastropub  0.05
#
#
# ----Caledonia-Fairbanks----
#             venue  freq
# 0        Bus Stop  0.09
# 1            Park  0.09
# 2        Pharmacy  0.09
# 3  Cosmetics Shop  0.05
# 4          Market  0.05
#
#
# ----Canada Post Gateway Processing Centre----
#                        venue  freq
# 0                Coffee Shop  0.11
# 1  Middle Eastern Restaurant  0.05
# 2                      Hotel  0.05
# 3               Intersection  0.04
# 4         Mexican Restaurant  0.04
#
#
# ----Cedarbrae----
#                venue  freq
# 0        Coffee Shop  0.10
# 1             Bakery  0.10
# 2  Indian Restaurant  0.07
# 3        Gas Station  0.07
# 4           Pharmacy  0.07
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1  Japanese Restaurant  0.04
# 2                 Park  0.03
# 3   Italian Restaurant  0.03
# 4          Art Gallery  0.03
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                            venue  freq
# 0                           Café  0.10
# 1                            Bar  0.08
# 2  Vegetarian / Vegan Restaurant  0.06
# 3          Vietnamese Restaurant  0.04
# 4                         Bakery  0.04
#
#
# ----Christie----
#                venue  freq
# 0  Korean Restaurant  0.13
# 1               Café  0.07
# 2        Coffee Shop  0.06
# 3      Grocery Store  0.05
# 4       Cocktail Bar  0.03
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1  Japanese Restaurant  0.05
# 2                 Park  0.04
# 3                 Café  0.03
# 4              Gay Bar  0.03
#
#
# ----Clairlea, Golden Mile, Oakridge----
#           venue  freq
# 0      Bus Line  0.08
# 1  Intersection  0.08
# 2         Diner  0.08
# 3        Bakery  0.08
# 4   Coffee Shop  0.08
#
#
# ----Clarks Corners, Sullivan, Tam O'Shanter----
#                   venue  freq
# 0           Coffee Shop  0.09
# 1  Fast Food Restaurant  0.06
# 2        Sandwich Place  0.06
# 3           Pizza Place  0.06
# 4         Shopping Mall  0.06
#
#
# ----Cliffcrest, Cliffside, Scarborough Village West----
#             venue  freq
# 0     Pizza Place  0.25
# 1  Ice Cream Shop  0.17
# 2           Beach  0.17
# 3  Hardware Store  0.08
# 4      Sports Bar  0.08
#
#
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
#                 venue  freq
# 0                Park  0.20
# 1         Pizza Place  0.13
# 2   Convenience Store  0.07
# 3  Mexican Restaurant  0.07
# 4   Fish & Chips Shop  0.07
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                 Café  0.07
# 2                Hotel  0.07
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.07
# 2    Sushi Restaurant  0.06
# 3                 Pub  0.03
# 4                Café  0.03
#
#
# ----Davisville North----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1    Italian Restaurant  0.05
# 2                  Café  0.04
# 3  Fast Food Restaurant  0.04
# 4          Dessert Shop  0.03
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1    Sushi Restaurant  0.06
# 2                Park  0.05
# 3  Italian Restaurant  0.05
# 4          Restaurant  0.04
#
#
# ----Del Ray, Keelesdale, Mount Dennis, Silverthorn----
#                     venue  freq
# 0  Furniture / Home Store  0.17
# 1          Discount Store  0.11
# 2           Grocery Store  0.11
# 3       Convenience Store  0.06
# 4             Gas Station  0.06
#
#
# ----Design Exchange, Toronto Dominion Centre----
#                 venue  freq
# 0                Café  0.07
# 1         Coffee Shop  0.07
# 2               Hotel  0.06
# 3          Restaurant  0.05
# 4  Italian Restaurant  0.04
#
#
# ----Don Mills North----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1  Japanese Restaurant  0.09
# 2          Pizza Place  0.09
# 3         Burger Joint  0.06
# 4                  Bar  0.03
#
#
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
#                     venue  freq
# 0       Electronics Store  0.09
# 1             Coffee Shop  0.07
# 2       Indian Restaurant  0.05
# 3    Fast Food Restaurant  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----Dovercourt Village, Dufferin----
#               venue  freq
# 0              Café  0.10
# 1              Park  0.09
# 2       Coffee Shop  0.09
# 3               Bar  0.04
# 4  Sushi Restaurant  0.04
#
#
# ----Downsview Central----
#                      venue  freq
# 0    Vietnamese Restaurant  0.50
# 1           Baseball Field  0.25
# 2          Thai Restaurant  0.25
# 3                      Zoo  0.00
# 4  New American Restaurant  0.00
#
#
# ----Downsview Northwest----
#                   venue  freq
# 0                 Hotel  0.13
# 1           Pizza Place  0.06
# 2           Gas Station  0.06
# 3           Coffee Shop  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ----Downsview West----
#                    venue  freq
# 0                   Park  0.25
# 1  Vietnamese Restaurant  0.12
# 2          Grocery Store  0.12
# 3            Coffee Shop  0.12
# 4            Pizza Place  0.12
#
#
# ----Downsview, North Park, Upwood Park----
#                       venue  freq
# 0               Coffee Shop  0.18
# 1         Convenience Store  0.09
# 2        Dim Sum Restaurant  0.09
# 3  Mediterranean Restaurant  0.09
# 4               Gas Station  0.09
#
#
# ----East Birchmount Park, Ionview, Kennedy Park----
#                   venue  freq
# 0           Coffee Shop  0.14
# 1    Chinese Restaurant  0.10
# 2        Discount Store  0.07
# 3  Fast Food Restaurant  0.07
# 4     Convenience Store  0.07
#
#
# ----East Toronto----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1                  Café  0.07
# 2      Greek Restaurant  0.06
# 3  Ethiopian Restaurant  0.03
# 4                   Bar  0.03
#
#
# ----Emery, Humberlea----
#                venue  freq
# 0  Convenience Store  0.12
# 1       Intersection  0.12
# 2   Storage Facility  0.12
# 3        Gas Station  0.12
# 4        Golf Course  0.12
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.14
# 1           Coffee Shop  0.11
# 2  Fast Food Restaurant  0.05
# 3        Sandwich Place  0.05
# 4   Japanese Restaurant  0.05
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0                Hotel  0.07
# 1                 Café  0.07
# 2          Coffee Shop  0.06
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----Flemingdon Park, Don Mills South----
#                  venue  freq
# 0           Restaurant  0.11
# 1                  Gym  0.07
# 2          Coffee Shop  0.07
# 3  Japanese Restaurant  0.07
# 4           Beer Store  0.05
#
#
# ----Forest Hill North, Forest Hill West----
#                   venue  freq
# 0                  Park  0.10
# 1  Gym / Fitness Center  0.06
# 2                  Café  0.06
# 3      Sushi Restaurant  0.06
# 4           Coffee Shop  0.06
#
#
# ----Glencairn----
#                   venue  freq
# 0         Grocery Store  0.12
# 1  Fast Food Restaurant  0.09
# 2           Gas Station  0.06
# 3                  Park  0.06
# 4           Coffee Shop  0.06
#
#
# ----Guildwood, Morningside, West Hill----
#                   venue  freq
# 0           Pizza Place  0.14
# 1  Fast Food Restaurant  0.09
# 2           Coffee Shop  0.09
# 3     Food & Drink Shop  0.05
# 4             Juice Bar  0.05
#
#
# ----Harbord, University of Toronto----
#                            venue  freq
# 0                           Café  0.09
# 1  Vegetarian / Vegan Restaurant  0.05
# 2                            Bar  0.05
# 3                         Bakery  0.05
# 4                    Coffee Shop  0.04
#
#
# ----Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.15
# 1         Café  0.05
# 2         Park  0.04
# 3      Theater  0.04
# 4        Diner  0.04
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1                Café  0.05
# 2               Hotel  0.05
# 3          Restaurant  0.05
# 4  Italian Restaurant  0.04
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0                Café  0.08
# 1                 Bar  0.08
# 2         Coffee Shop  0.06
# 3  Italian Restaurant  0.04
# 4     Thai Restaurant  0.04
#
#
# ----Highland Creek, Rouge Hill, Port Union----
#                 venue  freq
# 0                Park   0.2
# 1        Burger Joint   0.2
# 2          Playground   0.2
# 3  Italian Restaurant   0.2
# 4      Breakfast Spot   0.2
#
#
# ----Hillcrest Village----
#                venue  freq
# 0               Park  0.10
# 1        Coffee Shop  0.10
# 2           Pharmacy  0.10
# 3  Convenience Store  0.05
# 4        Pizza Place  0.05
#
#
# ----Humber Bay Shores, Mimico South, New Toronto----
#           venue  freq
# 0          Café  0.11
# 1          Park  0.11
# 2   Pizza Place  0.05
# 3        Bakery  0.05
# 4  Skating Rink  0.05
#
#
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
#                          venue  freq
# 0           Italian Restaurant  0.29
# 1                         Park  0.29
# 2  Eastern European Restaurant  0.14
# 3                Shopping Mall  0.14
# 4               Ice Cream Shop  0.14
#
#
# ----Humber Summit----
#            venue  freq
# 0         Bakery   0.1
# 1    Pizza Place   0.1
# 2           Bank   0.1
# 3  Shopping Mall   0.1
# 4           Park   0.1
#
#
# ----Humewood-Cedarvale----
#                        venue  freq
# 0          Food & Drink Shop  0.08
# 1                Pizza Place  0.08
# 2                Coffee Shop  0.08
# 3                       Park  0.08
# 4  Middle Eastern Restaurant  0.04
#
#
# ----Islington Avenue----
#                venue  freq
# 0           Pharmacy  0.17
# 1  Convenience Store  0.08
# 2               Café  0.08
# 3       Skating Rink  0.08
# 4      Shopping Mall  0.08
#
#
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
#          venue  freq
# 0     Pharmacy  0.13
# 1     Bus Line  0.07
# 2  Pizza Place  0.07
# 3         Bank  0.07
# 4   Beer Store  0.07
#
#
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
#                   venue  freq
# 0            Restaurant  0.08
# 1  Gym / Fitness Center  0.05
# 2           Coffee Shop  0.05
# 3         Burrito Place  0.05
# 4           Yoga Studio  0.03
#
#
# ----L'Amoreaux West----
#                   venue  freq
# 0    Chinese Restaurant  0.15
# 1  Fast Food Restaurant  0.07
# 2           Coffee Shop  0.07
# 3           Pizza Place  0.07
# 4                Bakery  0.07
#
#
# ----Lawrence Heights, Lawrence Manor----
#                     venue  freq
# 0    Fast Food Restaurant  0.07
# 1             Coffee Shop  0.07
# 2              Restaurant  0.07
# 3  Furniture / Home Store  0.05
# 4            Dessert Shop  0.05
#
#
# ----Lawrence Park----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1                 Trail  0.12
# 2             Bookstore  0.12
# 3  Gym / Fitness Center  0.12
# 4                  Café  0.12
#
#
# ----Leaside----
#                     venue  freq
# 0     Sporting Goods Shop  0.06
# 1             Coffee Shop  0.06
# 2  Furniture / Home Store  0.05
# 3           Grocery Store  0.05
# 4       Electronics Store  0.05
#
#
# ----Little Portugal, Trinity----
#          venue  freq
# 0         Café  0.08
# 1          Bar  0.08
# 2       Bakery  0.06
# 3  Coffee Shop  0.05
# 4   Restaurant  0.05
#
#
# ----Maryvale, Wexford----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.13
# 1              Grocery Store  0.07
# 2               Burger Joint  0.07
# 3                Pizza Place  0.07
# 4                Gas Station  0.03
#
#
# ----Moore Park, Summerhill East----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1  Italian Restaurant  0.06
# 2     Thai Restaurant  0.05
# 3       Grocery Store  0.05
# 4          Restaurant  0.05
#
#
# ----Newtonbrook, Willowdale----
#                        venue  freq
# 0          Korean Restaurant  0.12
# 1                       Café  0.09
# 2  Middle Eastern Restaurant  0.06
# 3                   Bus Line  0.06
# 4                Coffee Shop  0.06
#
#
# ----North Toronto West----
#                  venue  freq
# 0   Italian Restaurant  0.07
# 1          Coffee Shop  0.07
# 2                Diner  0.05
# 3   Mexican Restaurant  0.05
# 4  Sporting Goods Shop  0.05
#
#
# ----Northwest----
#                   venue  freq
# 0             Drugstore   0.5
# 1           Coffee Shop   0.5
# 2  Pakistani Restaurant   0.0
# 3     Other Repair Shop   0.0
# 4  Other Great Outdoors   0.0
#
#
# ----Northwood Park, York University----
#                     venue  freq
# 0  Furniture / Home Store  0.12
# 1             Coffee Shop  0.12
# 2             Pizza Place  0.12
# 3              Restaurant  0.08
# 4                     Bar  0.04
#
#
# ----Parkdale, Roncesvalles----
#               venue  freq
# 0              Café  0.05
# 1       Coffee Shop  0.05
# 2        Restaurant  0.04
# 3  Sushi Restaurant  0.04
# 4    Breakfast Spot  0.04
#
#
# ----Parkwoods----
#                venue  freq
# 0               Park  0.10
# 1      Shopping Mall  0.07
# 2           Pharmacy  0.07
# 3           Bus Stop  0.07
# 4  Convenience Store  0.07
#
#
# ----Queen's Park----
#               venue  freq
# 0       Coffee Shop  0.10
# 1         Gastropub  0.04
# 2              Park  0.04
# 3  Sushi Restaurant  0.03
# 4      Burger Joint  0.03
#
#
# ----Rosedale----
#            venue  freq
# 0    Coffee Shop  0.12
# 1  Grocery Store  0.08
# 2           Park  0.08
# 3       Pie Shop  0.04
# 4         Office  0.04
#
#
# ----Roselawn----
#                 venue  freq
# 0    Sushi Restaurant  0.15
# 1  Italian Restaurant  0.08
# 2                 Gym  0.08
# 3                Bank  0.08
# 4            Pharmacy  0.08
#
#
# ----Rouge, Malvern----
#                   venue  freq
# 0  Fast Food Restaurant  0.12
# 1                 Trail  0.12
# 2                   Gym  0.06
# 3        Sandwich Place  0.06
# 4  Caribbean Restaurant  0.06
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1                Café  0.09
# 2         Pizza Place  0.05
# 3              Bakery  0.05
# 4  Italian Restaurant  0.04
#
#
# ----Ryerson, Garden District----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1       Clothing Store  0.05
# 2  Japanese Restaurant  0.03
# 3   Italian Restaurant  0.03
# 4     Ramen Restaurant  0.03
#
#
# ----Scarborough Village----
#                   venue  freq
# 0        Ice Cream Shop  0.17
# 1     Convenience Store  0.08
# 2           Pizza Place  0.08
# 3         Bowling Alley  0.08
# 4  Fast Food Restaurant  0.08
#
#
# ----Silver Hills, York Mills----
#              venue  freq
# 0             Park  0.75
# 1             Pool  0.25
# 2              Zoo  0.00
# 3       Nail Salon  0.00
# 4  Organic Grocery  0.00
#
#
# ----St. James Town----
#          venue  freq
# 0  Coffee Shop  0.09
# 1         Café  0.07
# 2       Bakery  0.04
# 3   Restaurant  0.04
# 4        Hotel  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1                 Café  0.07
# 2           Restaurant  0.06
# 3  Japanese Restaurant  0.05
# 4             Beer Bar  0.04
#
#
# ----Studio District----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1                  Bar  0.06
# 2                 Café  0.05
# 3  American Restaurant  0.04
# 4   Italian Restaurant  0.04
#
#
# ----The Annex, North Midtown, Yorkville----
#                            venue  freq
# 0                           Café  0.06
# 1             Italian Restaurant  0.04
# 2                            Pub  0.04
# 3                            Gym  0.04
# 4  Vegetarian / Vegan Restaurant  0.04
#
#
# ----The Beaches----
#             venue  freq
# 0     Coffee Shop  0.07
# 1             Pub  0.07
# 2     Pizza Place  0.05
# 3  Breakfast Spot  0.04
# 4           Beach  0.04
#
#
# ----The Beaches West, India Bazaar----
#                venue  freq
# 0  Indian Restaurant  0.08
# 1        Coffee Shop  0.05
# 2               Park  0.05
# 3               Café  0.04
# 4        Pizza Place  0.04
#
#
# ----The Danforth West, Riverdale----
#               venue  freq
# 0  Greek Restaurant  0.13
# 1              Café  0.06
# 2       Coffee Shop  0.06
# 3               Pub  0.05
# 4       Pizza Place  0.03
#
#
# ----The Junction North, Runnymede----
#          venue  freq
# 0  Coffee Shop  0.12
# 1     Bus Line  0.07
# 2      Brewery  0.07
# 3  Pizza Place  0.07
# 4         Park  0.05
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#               venue  freq
# 0       Coffee Shop  0.09
# 1      Burger Joint  0.04
# 2  Sushi Restaurant  0.04
# 3               Pub  0.04
# 4       Pizza Place  0.04
#
#
# ----Thorncliffe Park----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1   Indian Restaurant  0.06
# 2       Grocery Store  0.06
# 3  Turkish Restaurant  0.04
# 4             Brewery  0.04
#
#
# ----Victoria Village----
#           venue  freq
# 0   Coffee Shop  0.15
# 1   Golf Course  0.08
# 2  Intersection  0.08
# 3          Park  0.08
# 4        Lounge  0.08
#
#
# ----Westmount----
#             venue  freq
# 0     Pizza Place  0.17
# 1     Gas Station  0.11
# 2  Ice Cream Shop  0.06
# 3  Discount Store  0.06
# 4     Flea Market  0.06
#
#
# ----Weston----
#             venue  freq
# 0            Park  0.11
# 1   Train Station  0.11
# 2     Coffee Shop  0.11
# 3        Pharmacy  0.06
# 4  Breakfast Spot  0.06
#
#
# ----Willowdale South----
#                venue  freq
# 0   Ramen Restaurant  0.06
# 1        Coffee Shop  0.06
# 2        Pizza Place  0.05
# 3  Korean Restaurant  0.05
# 4    Bubble Tea Shop  0.05
#
#
# ----Willowdale West----
#                          venue  freq
# 0                     Pharmacy  0.15
# 1                       Bakery  0.08
# 2                  Coffee Shop  0.08
# 3  Eastern European Restaurant  0.08
# 4                     Bus Line  0.08
#
#
# ----Woburn----
#                 venue  freq
# 0                Park   0.2
# 1         Coffee Shop   0.2
# 2  Chinese Restaurant   0.1
# 3   Mobile Phone Shop   0.1
# 4   Indian Restaurant   0.1
#
#
# ----Woodbine Gardens, Parkview Hill----
#             venue  freq
# 0     Pizza Place  0.10
# 1         Brewery  0.10
# 2      Restaurant  0.05
# 3            Café  0.05
# 4  Breakfast Spot  0.05
#
#
# ----Woodbine Heights----
#             venue  freq
# 0            Park  0.10
# 1     Coffee Shop  0.10
# 2    Skating Rink  0.07
# 3  Sandwich Place  0.07
# 4     Pizza Place  0.07
#
#
# ----York Mills West----
#           venue  freq
# 0          Park  0.14
# 1   Coffee Shop  0.14
# 2    Restaurant  0.14
# 3  Tennis Court  0.09
# 4   Gas Station  0.05

# %% [markdown]
# define a function to calculate the most common venues in each neighborhood

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# invoke the function and create a dataframe of the top ten venue categories in each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = grouped['Neighborhood']

for ind in np.arange(grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond                  Café
# 1                                          Agincourt    Chinese Restaurant
# 2  Agincourt North, L'Amoreaux East, Milliken, St...    Chinese Restaurant
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...           Pizza Place
# 4                             Alderwood, Long Branch        Discount Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop                 Hotel               Theater
# 1  Caribbean Restaurant         Shopping Mall            Restaurant
# 2                Bakery                  Park           Pizza Place
# 3         Grocery Store              Pharmacy        Sandwich Place
# 4              Pharmacy           Pizza Place           Coffee Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Restaurant      Sushi Restaurant                Bakery
# 1                Bakery                  Park     Indian Restaurant
# 2  Fast Food Restaurant          Noodle House           Event Space
# 3        Discount Store          Liquor Store            Beer Store
# 4   Moroccan Restaurant          Skating Rink         Shopping Mall
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Pizza Place        Breakfast Spot     Seafood Restaurant
# 1            Print Shop        Clothing Store    Shanghai Restaurant
# 2      Malay Restaurant         Shopping Mall         Shop & Service
# 3                  Park   Fried Chicken Joint    Japanese Restaurant
# 4          Liquor Store            Donut Shop         Sandwich Place

# %% [markdown]
# perform k-means clustering on the dataframe to see which neighborhoods are similar

# %%
kclusters = 5
grouped_clustering = grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# %%
kmeans.labels_[0:10]
# Out:
# array([2, 0, 0, 0, 0, 2, 2, 2, 2, 2])

# %% [markdown]
# add the cluster labels as a column in the dataframe

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster labels', kmeans.labels_)
merged = agg2
merged = merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')
merged.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353             0.0  Fast Food Restaurant                 Trail
# 1 -79.160497             2.0        Breakfast Spot            Playground
# 2 -79.188711             0.0           Pizza Place  Fast Food Restaurant
# 3 -79.216917             0.0                  Park           Coffee Shop
# 4 -79.239476             0.0                Bakery           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Coffee Shop   Arts & Crafts Store    Chinese Restaurant
# 1          Burger Joint                  Park    Italian Restaurant
# 2           Coffee Shop                  Bank            Restaurant
# 3    Chinese Restaurant     Indian Restaurant  Fast Food Restaurant
# 4              Pharmacy           Gas Station     Indian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0                Bakery  Caribbean Restaurant      Fruit & Vegetable Store
# 1    Falafel Restaurant   Dumpling Restaurant  Eastern European Restaurant
# 2            Sports Bar     Food & Drink Shop                 Liquor Store
# 3      Business Service              Pharmacy            Mobile Phone Shop
# 4   Sporting Goods Shop                  Bank          Fried Chicken Joint
#
#            9th Most Common Venue 10th Most Common Venue
# 0  Paper / Office Supplies Store             Restaurant
# 1              Electronics Store    Empanada Restaurant
# 2                    Supermarket             Beer Store
# 3                  Deli / Bodega     Falafel Restaurant
# 4                         Lounge            Yoga Studio

# %% [markdown]
# examine the neighborhoods of each cluster

# %%
merged.loc[merged['Cluster labels'] == 4, merged.columns[[1] + list(range(5, merged.shape[1]))]]
# Out:
#        Borough  Cluster labels  1st Most Common Venue 2nd Most Common Venue  \
# 32  North York             4.0  Vietnamese Restaurant       Thai Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 32        Baseball Field           Yoga Studio           Event Space
#
#    6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 32             Drugstore   Dumpling Restaurant  Eastern European Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 32     Electronics Store    Empanada Restaurant

# %% [markdown]
# check for null cluster values as the postcode list and lat/lon data may disagree, thus a neighborhood may not have Foursquare data

# %%
merged[merged['Cluster labels'].isnull()]
# Out:
#    Postcode      Borough Neighbourhood   Latitude  Longitude  Cluster labels  \
# 16      M1X  Scarborough   Upper Rouge  43.836125 -79.205636             NaN
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 16                   NaN                   NaN                   NaN
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
#
#    10th Most Common Venue
# 16                    NaN

# %% [markdown]
# drop rows with nulls

# %%
merged = merged.dropna()

# %%
merged[merged['Cluster labels'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood, Latitude, Longitude, Cluster labels, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %% [markdown]
# cast cluster labels to integers

# %%
merged['Cluster labels'] = merged['Cluster labels'].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# define a map object located on Toronto's lat/lon coordinates

# %%
map_clusters = folium.Map(location=[43.65, -79.38], zoom_start=10)

# %% [markdown]
# set a color palatte based on the number of clusters

# %%
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %% [markdown]
# create a list of map markers using each neighborhood's cluster label

# %%
markers_colors = []
for lat, lon, poi, cluster in zip(merged['Latitude'], merged['Longitude'], merged['Neighbourhood'], merged['Cluster labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

# %% [markdown]
# display the map

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
